# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
pd.set_option('display.max_columns', None)

# %%
data = pd.read_csv('healthinsurance.csv')
data
# Out:
#         age     sex  weight   bmi hereditary_diseases  no_of_dependents  \
# 0      60.0    male      64  24.3           NoDisease                 1
# 1      49.0  female      75  22.6           NoDisease                 1
# 2      32.0  female      64  17.8            Epilepsy                 2
# 3      61.0  female      53  36.4           NoDisease                 1
# 4      19.0  female      50  20.6           NoDisease                 0
# ...     ...     ...     ...   ...                 ...               ...
# 14995  39.0    male      49  28.3           NoDisease                 1
# 14996  39.0    male      74  29.6           NoDisease                 4
# 14997  20.0    male      62  33.3           NoDisease                 0
# 14998  52.0    male      88  36.7           NoDisease                 0
# 14999  52.0    male      57  26.4           NoDisease                 3
#
#        smoker         city  bloodpressure  diabetes  regular_ex  \
# ...

# %% [markdown]
# # Exploratory Descriptive Analysis

# %%
data.shape
# Out:
# (15000, 13)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   age                  14604 non-null  float64
#  1   sex                  15000 non-null  object
#  2   weight               15000 non-null  int64
#  3   bmi                  14044 non-null  float64
#  4   hereditary_diseases  15000 non-null  object
#  5   no_of_dependents     15000 non-null  int64
#  6   smoker               15000 non-null  int64
#  7   city                 15000 non-null  object
#  8   bloodpressure        15000 non-null  int64
#  9   diabetes             15000 non-null  int64
#  10  regular_ex           15000 non-null  int64
#  11  job_title            15000 non-null  object
#  12  claim                15000 non-null  float64
# dtypes: float64(3), int64(6), object(4)
# memory usage: 1.5+ MB

# %%
data.describe()
# Out:
#                 age        weight           bmi  no_of_dependents  \
# count  14604.000000  15000.000000  14044.000000      15000.000000
# mean      39.547521     64.909600     30.266413          1.129733
# std       14.015966     13.701935      6.122950          1.228469
# min       18.000000     34.000000     16.000000          0.000000
# 25%       27.000000     54.000000     25.700000          0.000000
# 50%       40.000000     63.000000     29.400000          1.000000
# 75%       52.000000     76.000000     34.400000          2.000000
# max       64.000000     95.000000     53.100000          5.000000
#
#              smoker  bloodpressure      diabetes    regular_ex         claim
# count  15000.000000   15000.000000  15000.000000  15000.000000  15000.000000
# mean       0.198133      68.650133      0.777000      0.224133  13401.437620
# std        0.398606      19.418515      0.416272      0.417024  12148.239619
# ...

# %%
data.columns
# Out:
# Index(['age', 'sex', 'weight', 'bmi', 'hereditary_diseases',
#        'no_of_dependents', 'smoker', 'city', 'bloodpressure', 'diabetes',
#        'regular_ex', 'job_title', 'claim'],
#       dtype='object')

# %%
data.index
# Out:
# RangeIndex(start=0, stop=15000, step=1)

# %%
data.nunique()
# Out:
# age                      47
# sex                       2
# weight                   58
# bmi                     269
# hereditary_diseases      10
# no_of_dependents          6
# smoker                    2
# city                     91
# bloodpressure            69
# diabetes                  2
# regular_ex                2
# job_title                35
# claim                  2054
# dtype: int64

# %% [markdown]
# # Duplicated Rows

# %%
data[data.duplicated(keep='first')]
# Out:
#         age     sex  weight   bmi hereditary_diseases  no_of_dependents  \
# 605    46.0  female      68   NaN           NoDisease                 2
# 608    27.0  female      82   NaN           NoDisease                 3
# 898    48.0  female      67  33.1           Alzheimer                 0
# 919    26.0    male      56  23.7           NoDisease                 2
# 970    48.0  female      70  28.9           NoDisease                 1
# ...     ...     ...     ...   ...                 ...               ...
# 14966  46.0    male      46  22.3           NoDisease                 0
# 14971  18.0  female      53  27.3           NoDisease                 3
# 14987  47.0    male      94  47.5           NoDisease                 1
# 14989  44.0    male      90  38.1           NoDisease                 1
# 14997  20.0    male      62  33.3           NoDisease                 0
#
#        smoker        city  bloodpressure  diabetes  regular_ex  \
# ...

# %% [markdown]
# # Drop Duplicated Rows

# %%
data = data.drop_duplicates(keep='first')
data = data.reset_index(drop=True)
data
# Out:
#         age     sex  weight   bmi hereditary_diseases  no_of_dependents  \
# 0      60.0    male      64  24.3           NoDisease                 1
# 1      49.0  female      75  22.6           NoDisease                 1
# 2      32.0  female      64  17.8            Epilepsy                 2
# 3      61.0  female      53  36.4           NoDisease                 1
# 4      19.0  female      50  20.6           NoDisease                 0
# ...     ...     ...     ...   ...                 ...               ...
# 13899  38.0  female      71  27.3           NoDisease                 1
# 13900  39.0    male      49  28.3           NoDisease                 1
# 13901  39.0    male      74  29.6           NoDisease                 4
# 13902  52.0    male      88  36.7           NoDisease                 0
# 13903  52.0    male      57  26.4           NoDisease                 3
#
#        smoker         city  bloodpressure  diabetes  regular_ex    job_title  \
# ...

# %% [markdown]
# # Checking Null values

# %%
missing_values = data.isna().sum()
missing_values
# Out:
# age                    361
# sex                      0
# weight                   0
# bmi                    901
# hereditary_diseases      0
# no_of_dependents         0
# smoker                   0
# city                     0
# bloodpressure            0
# diabetes                 0
# regular_ex               0
# job_title                0
# claim                    0
# dtype: int64

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x=missing_values.index, y=missing_values.values)
plt.ylabel('Number of Missing Values')
plt.title('Missing Values in Each Column')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # Data types

# %%
data.dtypes
# Out:
# age                    float64
# sex                     object
# weight                   int64
# bmi                    float64
# hereditary_diseases     object
# no_of_dependents         int64
# smoker                   int64
# city                    object
# bloodpressure            int64
# diabetes                 int64
# regular_ex               int64
# job_title               object
# claim                  float64
# dtype: object

# %% [markdown]
# # Unique values in each column

# %%
data.nunique()
# Out:
# age                      47
# sex                       2
# weight                   58
# bmi                     269
# hereditary_diseases      10
# no_of_dependents          6
# smoker                    2
# city                     91
# bloodpressure            69
# diabetes                  2
# regular_ex                2
# job_title                35
# claim                  2054
# dtype: int64

# %%
categorical_columns = ['sex','hereditary_diseases','no_of_dependents','smoker','city','diabetes','regular_ex','job_title']
numerical_columns = ['age','weight','bmi','bloodpressure']

# %% [markdown]
# # Convertig dtypes

# %%
for col in categorical_columns:
    data[col] = data[col].astype(object)

# %%
for col in numerical_columns:
    data[col] = data[col].astype(float)

# %%
data.dtypes
# Out:
# age                    float64
# sex                     object
# weight                 float64
# bmi                    float64
# hereditary_diseases     object
# no_of_dependents        object
# smoker                  object
# city                    object
# bloodpressure          float64
# diabetes                object
# regular_ex              object
# job_title               object
# claim                  float64
# dtype: object

# %% [markdown]
# # Bar Plot of Categorical colums

# %%
plt.figure(figsize=(15, 12))
for i, col in enumerate(categorical_columns):
    plt.subplot(3, 3, i + 1)  # Adjust the number of rows and columns as needed
    sns.countplot(x=data[col])
    plt.title(col)
    plt.xlabel('')
    plt.ylabel('Count')
    plt.xticks(rotation=45)

plt.tight_layout()

# %% [markdown]
# # Distribution plot for continuous values

# %%
plt.figure(figsize=(15, 12))

# Create a subplot for each numerical column
for i, col in enumerate(numerical_columns):
    plt.subplot(2, 2, i + 1)  # Adjust the number of rows and columns as needed
    sns.histplot(data[col], kde=True)
    plt.title(col)
    plt.xlabel('')
    plt.ylabel('Density')

plt.tight_layout()
plt.show()

# %%
corr_matrix = data[numerical_columns].corr()

# Create a heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f", annot_kws={"size": 10})
plt.title('Correlation Heatmap of Numerical Columns')
plt.show()

# %% [markdown]
# # Box plot for numerical_columns

# %%
plt.figure(figsize=(10, 8))
for i, col in enumerate(numerical_columns):
    plt.subplot(2, 2, i + 1)
    sns.boxplot(y=data[col])
    plt.title(f'Boxplot of {col}')
    plt.ylabel(col)

plt.tight_layout()
plt.show()

# %% [markdown]
# # Removing outliers in numerical columns using Z score

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
sc.fit(data[numerical_columns])
# Out:
# StandardScaler()

# %%
z_scaled_df = pd.DataFrame(sc.transform(data[numerical_columns]),
                          columns=numerical_columns)

# %%
z_scaled_df.bloodpressure.min()
# Out:
# -3.5336235235910487

# %%
def check_z(x):
    return (x >= 3) or (x <= -3)

# %%
outlier_indices = set()
for col in numerical_columns:
    temp = z_scaled_df[z_scaled_df[col].apply(check_z)]
    if temp.shape[0] != 0:
        outlier_indices.update(temp.index)

# %%
len(outlier_indices)
# Out:
# 738

# %% [markdown]
# # Dropping outliers

# %%
data = data.drop(index=outlier_indices)
data = data.reset_index(drop=True)
data
# Out:
#         age     sex  weight   bmi hereditary_diseases no_of_dependents smoker  \
# 0      60.0    male    64.0  24.3           NoDisease                1      0
# 1      49.0  female    75.0  22.6           NoDisease                1      0
# 2      32.0  female    64.0  17.8            Epilepsy                2      1
# 3      61.0  female    53.0  36.4           NoDisease                1      1
# 4      19.0  female    50.0  20.6           NoDisease                0      0
# ...     ...     ...     ...   ...                 ...              ...    ...
# 13161  56.0  female    55.0  25.7           NoDisease                0      0
# 13162  39.0    male    49.0  28.3           NoDisease                1      1
# 13163  39.0    male    74.0  29.6           NoDisease                4      0
# 13164  52.0    male    88.0  36.7           NoDisease                0      0
# 13165  52.0    male    57.0  26.4           NoDisease                3      0
#
# ...

# %% [markdown]
# # Fill missing values with median

# %%
data['age'].median(), data['bmi'].median()
# Out:
# (40.0, 29.3)

# %%
data = data.assign(age = data['age'].fillna(data.age.median()))
data = data.assign(bmi = data['bmi'].fillna(data.bmi.median()))
data
# Out:
#         age     sex  weight   bmi hereditary_diseases no_of_dependents smoker  \
# 0      60.0    male    64.0  24.3           NoDisease                1      0
# 1      49.0  female    75.0  22.6           NoDisease                1      0
# 2      32.0  female    64.0  17.8            Epilepsy                2      1
# 3      61.0  female    53.0  36.4           NoDisease                1      1
# 4      19.0  female    50.0  20.6           NoDisease                0      0
# ...     ...     ...     ...   ...                 ...              ...    ...
# 13161  56.0  female    55.0  25.7           NoDisease                0      0
# 13162  39.0    male    49.0  28.3           NoDisease                1      1
# 13163  39.0    male    74.0  29.6           NoDisease                4      0
# 13164  52.0    male    88.0  36.7           NoDisease                0      0
# 13165  52.0    male    57.0  26.4           NoDisease                3      0
#
# ...

# %%
data.isna().sum()
# Out:
# age                    0
# sex                    0
# weight                 0
# bmi                    0
# hereditary_diseases    0
# no_of_dependents       0
# smoker                 0
# city                   0
# bloodpressure          0
# diabetes               0
# regular_ex             0
# job_title              0
# claim                  0
# dtype: int64

# %%
data.nunique()
# Out:
# age                      47
# sex                       2
# weight                   58
# bmi                     262
# hereditary_diseases      10
# no_of_dependents          6
# smoker                    2
# city                     91
# bloodpressure            68
# diabetes                  2
# regular_ex                2
# job_title                35
# claim                  1947
# dtype: int64

# %%
plt.figure(figsize=(15, 12))
# Create a subplot for each numerical column
for i, col in enumerate(numerical_columns):
    plt.subplot(2, 2, i + 1)  # Adjust the number of rows and columns as needed
    sns.histplot(data[col], kde=True)
    plt.title(col)
    plt.xlabel('')
    plt.ylabel('Density')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Feature Selection of categorical columns with respect to target variable

# %%
categorical_columns
# Out:
# ['sex',
#  'hereditary_diseases',
#  'no_of_dependents',
#  'smoker',
#  'city',
#  'diabetes',
#  'regular_ex',
#  'job_title']

# %%
from scipy.stats import f_oneway
p_vals = {}
for col in categorical_columns:
    groups = [data['claim'][data[col] == category].values for category in data[col].unique()]
    p_val = f_oneway(*groups)[1]
    p_vals[col] = p_val
p_vals
# Out:
# {'sex': 1.060695486688871e-09,
#  'hereditary_diseases': 0.0,
#  'no_of_dependents': 9.67810893416751e-41,
#  'smoker': 0.0,
#  'city': 0.38034949331312323,
#  'diabetes': 1.3725350054487731e-49,
#  'regular_ex': 6.054677714054535e-15,
#  'job_title': 1.6794214297904195e-71}

# %%
significant_features , insignificant_features = [], []
for key, value in p_vals.items():
    if value < 0.05:
        significant_features.append(key)
    else:
        insignificant_features.append(key)

# %%
significant_features
# Out:
# ['sex',
#  'hereditary_diseases',
#  'no_of_dependents',
#  'smoker',
#  'diabetes',
#  'regular_ex',
#  'job_title']

# %%
insignificant_features
# Out:
# ['city']

# %% [markdown]
# # Dropping Insignificant Categorical feature

# %%
data = data.drop(columns= insignificant_features)
data
# Out:
#         age     sex  weight   bmi hereditary_diseases no_of_dependents smoker  \
# 0      60.0    male    64.0  24.3           NoDisease                1      0
# 1      49.0  female    75.0  22.6           NoDisease                1      0
# 2      32.0  female    64.0  17.8            Epilepsy                2      1
# 3      61.0  female    53.0  36.4           NoDisease                1      1
# 4      19.0  female    50.0  20.6           NoDisease                0      0
# ...     ...     ...     ...   ...                 ...              ...    ...
# 13161  56.0  female    55.0  25.7           NoDisease                0      0
# 13162  39.0    male    49.0  28.3           NoDisease                1      1
# 13163  39.0    male    74.0  29.6           NoDisease                4      0
# 13164  52.0    male    88.0  36.7           NoDisease                0      0
# 13165  52.0    male    57.0  26.4           NoDisease                3      0
#
# ...

# %%
data.shape
# Out:
# (13166, 12)

# %%
categorical_columns.remove('city')
categorical_columns

# %% [markdown]
# # Check and drop if independent categorical columns are correlated

# %%
from scipy.stats import chi2_contingency
from itertools import combinations

# %%
cat_combs = combinations(categorical_columns,2)
chi2_vals = {}
for comb in cat_combs:
    feat_a , feat_b = comb
    cross_tab = pd.crosstab(data[feat_a], data[feat_b])
    p_val = chi2_contingency(cross_tab)[1]
    chi2_vals[comb] = p_val

# %%
chi2_vals
# Out:
# {('sex', 'hereditary_diseases'): 1.4771175635998984e-21,
#  ('sex', 'no_of_dependents'): 0.00064495075274971,
#  ('sex', 'smoker'): 3.678534392230823e-16,
#  ('sex', 'diabetes'): 0.18509320671719967,
#  ('sex', 'regular_ex'): 0.0016862902131094576,
#  ('sex', 'job_title'): 1.5570973788168172e-89,
#  ('hereditary_diseases', 'no_of_dependents'): 1.912627486875836e-68,
#  ('hereditary_diseases', 'smoker'): 0.0,
#  ('hereditary_diseases', 'diabetes'): 4.762214014218066e-20,
#  ('hereditary_diseases', 'regular_ex'): 6.840992654761052e-12,
#  ('hereditary_diseases', 'job_title'): 0.0,
#  ('no_of_dependents', 'smoker'): 4.3076839047538696e-23,
#  ('no_of_dependents', 'diabetes'): 5.707866311958515e-34,
#  ('no_of_dependents', 'regular_ex'): 0.0007386727488627483,
#  ('no_of_dependents', 'job_title'): 0.0,
#  ('smoker', 'diabetes'): 1.7765250743423436e-09,
#  ('smoker', 'regular_ex'): 1.7269908812885304e-07,
#  ('smoker', 'job_title'): 7.410509452218167e-81,
# ...

# %%
significant_comb, insignificant_comb = [] , []
for comb, p_val in chi2_vals.items():
    if p_val <= 0.05:
        significant_comb.append(comb)
    else:
        insignificant_comb.append(comb)

# %%
significant_comb
# Out:
# [('sex', 'hereditary_diseases'),
#  ('sex', 'no_of_dependents'),
#  ('sex', 'smoker'),
#  ('sex', 'regular_ex'),
#  ('sex', 'job_title'),
#  ('hereditary_diseases', 'no_of_dependents'),
#  ('hereditary_diseases', 'smoker'),
#  ('hereditary_diseases', 'diabetes'),
#  ('hereditary_diseases', 'regular_ex'),
#  ('hereditary_diseases', 'job_title'),
#  ('no_of_dependents', 'smoker'),
#  ('no_of_dependents', 'diabetes'),
#  ('no_of_dependents', 'regular_ex'),
#  ('no_of_dependents', 'job_title'),
#  ('smoker', 'diabetes'),
#  ('smoker', 'regular_ex'),
#  ('smoker', 'job_title'),
#  ('diabetes', 'job_title'),
#  ('regular_ex', 'job_title')]

# %%
insignificant_comb
# Out:
# [('sex', 'diabetes'), ('diabetes', 'regular_ex')]

# %% [markdown]
# # Dropping Diabetes columns as it is correlated with 2 of the features

# %%
data = data.drop(columns= ['diabetes'])
data
# Out:
#         age     sex  weight   bmi hereditary_diseases no_of_dependents smoker  \
# 0      60.0    male    64.0  24.3           NoDisease                1      0
# 1      49.0  female    75.0  22.6           NoDisease                1      0
# 2      32.0  female    64.0  17.8            Epilepsy                2      1
# 3      61.0  female    53.0  36.4           NoDisease                1      1
# 4      19.0  female    50.0  20.6           NoDisease                0      0
# ...     ...     ...     ...   ...                 ...              ...    ...
# 13161  56.0  female    55.0  25.7           NoDisease                0      0
# 13162  39.0    male    49.0  28.3           NoDisease                1      1
# 13163  39.0    male    74.0  29.6           NoDisease                4      0
# 13164  52.0    male    88.0  36.7           NoDisease                0      0
# 13165  52.0    male    57.0  26.4           NoDisease                3      0
#
# ...

# %%
categorical_columns.remove('diabetes')
categorical_columns
# Out:
# ['sex',
#  'hereditary_diseases',
#  'no_of_dependents',
#  'smoker',
#  'regular_ex',
#  'job_title']

# %% [markdown]
# # Train Test Split

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_absolute_error
x = data.drop(columns='claim')
y = data['claim']
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25, random_state=45,stratify=data['job_title'])

# %%
x_train.shape
# Out:
# (9874, 10)

# %%
x_test.shape
# Out:
# (3292, 10)

# %% [markdown]
# # Frequency encoding for job_title column

# %%
job_title_freq = x_train['job_title'].value_counts()
job_title_freq
# Out:
# Student              877
# HomeMakers           663
# Singer               496
# FilmMaker            494
# Dancer               473
# Actor                459
# HouseKeeper          456
# Manager              411
# Police               277
# Accountant           258
# Politician           250
# FashionDesigner      248
# CEO                  241
# Clerks               236
# Photographer         234
# Architect            233
# Beautician           227
# Engineer             226
# DataScientist        215
# ITProfessional       214
# Doctor               212
# Academician          204
# Lawyer               200
# FilmDirector         191
# Blogger              188
# DefencePersonnels    187
# Journalist           185
# Chef                 182
# Analyst              179
# Farmer               176
# CA                   175
# Buisnessman          165
# GovEmployee          157
# Technician           147
# Labourer             138
# Name: job_title, dtype: int64

# %%
x_train['job_title'] = x_train['job_title'].map(job_title_freq)
x_train
# Out:
#         age     sex  weight   bmi hereditary_diseases no_of_dependents smoker  \
# 10703  27.0    male    63.0  32.7           NoDisease                0      0
# 10930  21.0    male    61.0  23.8           NoDisease                2      0
# 3886   51.0    male    59.0  39.7           NoDisease                1      0
# 9268   59.0    male    68.0  25.5           NoDisease                1      0
# 11326  32.0    male    78.0  37.3           NoDisease                1      0
# ...     ...     ...     ...   ...                 ...              ...    ...
# 8668   45.0    male    68.0  20.4           NoDisease                3      0
# 8232   23.0  female    54.0  24.2           NoDisease                2      0
# 7297   18.0    male    57.0  39.1           NoDisease                0      0
# 6396   47.0  female    60.0  29.5           NoDisease                1      0
# 5739   42.0  female    72.0  29.0           NoDisease                1      0
#
# ...

# %%
x_test['job_title'] = x_test['job_title'].map(job_title_freq)
x_test
# Out:
#         age     sex  weight   bmi hereditary_diseases no_of_dependents smoker  \
# 9925   53.0  female    80.0  23.8           NoDisease                2      0
# 3454   45.0  female    80.0  36.3           NoDisease                2      0
# 4745   40.0    male    48.0  23.5            Epilepsy                2      1
# 6549   57.0    male    60.0  18.3           NoDisease                0      0
# 10465  18.0    male    53.0  25.2           NoDisease                0      1
# ...     ...     ...     ...   ...                 ...              ...    ...
# 8598   22.0    male    47.0  28.9           NoDisease                0      0
# 5417   43.0    male    72.0  36.0           NoDisease                3      1
# 5772   45.0  female    80.0  36.3           NoDisease                2      0
# 4150   38.0    male    92.0  28.3           NoDisease                1      0
# 4272   57.0    male    60.0  35.3           NoDisease                1      0
#
# ...

# %% [markdown]
# # Onehot encoding categorical columns except job_title

# %%
categorical_columns
# Out:
# ['sex',
#  'hereditary_diseases',
#  'no_of_dependents',
#  'smoker',
#  'regular_ex',
#  'job_title']

# %%
from sklearn.preprocessing import OneHotEncoder
train_ohe_df = pd.DataFrame()
test_ohe_df = pd.DataFrame()

for col in categorical_columns:
    if col == 'job_title':
        continue
    ohe = OneHotEncoder(sparse=False)
    ohe.fit(x_train[[col]])
    train_df = pd.DataFrame(ohe.transform(x_train[[col]]),
                      columns= ohe.get_feature_names_out(),
                           index=x_train.index)
    test_df = pd.DataFrame(ohe.transform(x_test[[col]]),
                      columns= ohe.get_feature_names_out(),
                          index=x_test.index)
    train_ohe_df = pd.concat([train_ohe_df,train_df], axis=1)
    test_ohe_df = pd.concat([test_ohe_df,test_df], axis=1)

# %%
train_ohe_df
# Out:
#        sex_female  sex_male  hereditary_diseases_Alzheimer  \
# 10703         0.0       1.0                            0.0
# 10930         0.0       1.0                            0.0
# 3886          0.0       1.0                            0.0
# 9268          0.0       1.0                            0.0
# 11326         0.0       1.0                            0.0
# ...           ...       ...                            ...
# 8668          0.0       1.0                            0.0
# 8232          1.0       0.0                            0.0
# 7297          0.0       1.0                            0.0
# 6396          1.0       0.0                            0.0
# 5739          1.0       0.0                            0.0
#
#        hereditary_diseases_Arthritis  hereditary_diseases_Cancer  \
# 10703                            0.0                         0.0
# 10930                            0.0                         0.0
# ...

# %%
test_ohe_df
# Out:
#        sex_female  sex_male  hereditary_diseases_Alzheimer  \
# 9925          1.0       0.0                            0.0
# 3454          1.0       0.0                            0.0
# 4745          0.0       1.0                            0.0
# 6549          0.0       1.0                            0.0
# 10465         0.0       1.0                            0.0
# ...           ...       ...                            ...
# 8598          0.0       1.0                            0.0
# 5417          0.0       1.0                            0.0
# 5772          1.0       0.0                            0.0
# 4150          0.0       1.0                            0.0
# 4272          0.0       1.0                            0.0
#
#        hereditary_diseases_Arthritis  hereditary_diseases_Cancer  \
# 9925                             0.0                         0.0
# 3454                             0.0                         0.0
# ...

# %%
x_train_df = pd.concat([x_train[numerical_columns], x_train['job_title'],train_ohe_df,y_train], axis=1)
x_train_df
# Out:
#         age  weight   bmi  bloodpressure  job_title  sex_female  sex_male  \
# 10703  27.0    63.0  32.7           82.0        494         0.0       1.0
# 10930  21.0    61.0  23.8           60.0        188         0.0       1.0
# 3886   51.0    59.0  39.7           62.0        496         0.0       1.0
# 9268   59.0    68.0  25.5           90.0        663         0.0       1.0
# 11326  32.0    78.0  37.3           78.0        411         0.0       1.0
# ...     ...     ...   ...            ...        ...         ...       ...
# 8668   45.0    68.0  20.4           74.0        215         0.0       1.0
# 8232   23.0    54.0  24.2           76.0        663         1.0       0.0
# 7297   18.0    57.0  39.1           80.0        138         0.0       1.0
# 6396   47.0    60.0  29.5           76.0        182         1.0       0.0
# 5739   42.0    72.0  29.0           70.0        258         1.0       0.0
#
#        hereditary_diseases_Alzheimer  hereditary_diseases_Arthritis  \
# ...

# %%
x_test_df = pd.concat([x_test[numerical_columns], x_test['job_title'],test_ohe_df,y_test], axis=1)
x_test_df
# Out:
#         age  weight   bmi  bloodpressure  job_title  sex_female  sex_male  \
# 9925   53.0    80.0  23.8           74.0        147         1.0       0.0
# 3454   45.0    80.0  36.3           54.0        236         1.0       0.0
# 4745   40.0    48.0  23.5           74.0        248         0.0       1.0
# 6549   57.0    60.0  18.3           74.0        258         0.0       1.0
# 10465  18.0    53.0  25.2           56.0        473         0.0       1.0
# ...     ...     ...   ...            ...        ...         ...       ...
# 8598   22.0    47.0  28.9           86.0        877         0.0       1.0
# 5417   43.0    72.0  36.0           74.0        411         0.0       1.0
# 5772   45.0    80.0  36.3           54.0        236         1.0       0.0
# 4150   38.0    92.0  28.3           78.0        188         0.0       1.0
# 4272   57.0    60.0  35.3           90.0        877         0.0       1.0
#
#        hereditary_diseases_Alzheimer  hereditary_diseases_Arthritis  \
# ...

# %% [markdown]
# # Scaling

# %%
from sklearn.preprocessing import StandardScaler
ss = StandardScaler()
ss.fit(x_train_df)
# Out:
# StandardScaler()

# %%
x_train_scaled = pd.DataFrame(ss.transform(x_train_df),
                             index = x_train_df.index,
                             columns= x_train_df.columns)
x_test_scaled = pd.DataFrame(ss.transform(x_test_df),
                             index = x_test_df.index,
                             columns= x_test_df.columns)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import r2_score, mean_absolute_error

# %%
models = [LinearRegression(), DecisionTreeRegressor(), RandomForestRegressor(), KNeighborsRegressor()]
model_names = ['Linear Regression', 'Decision Tree', 'Random Forest', 'KNN']
train_r2, test_r2, train_mae, test_mae = [], [], [], []
for model_name, model in zip(model_names, models):
    model.fit(x_train_scaled, y_train)
    y_pred_train = model.predict(x_train_scaled)
    y_pred_test = model.predict(x_test_scaled)
    train_r2.append(round(r2_score(y_train, y_pred_train), 2))
    test_r2.append(round(r2_score(y_test, y_pred_test), 2))
    train_mae.append(round(mean_absolute_error(y_train, y_pred_train),2))
    test_mae.append(round(mean_absolute_error(y_test, y_pred_test), 2))
result_df = pd.DataFrame()
result_df['model_name'] = model_names
result_df['train_r2'] = train_r2
result_df['test_r2'] = test_r2
result_df['train_mae'] = train_mae
result_df['test_mae'] = test_mae
result_df
# Out:
#           model_name  train_r2  test_r2  train_mae  test_mae
# 0  Linear Regression      1.00     1.00       0.00      0.00
# 1      Decision Tree      1.00     1.00       0.00      8.29
# 2      Random Forest      1.00     1.00       0.75      3.43
# 3                KNN      0.98     0.97     319.38    497.38

# %% [markdown]
# # Calculating adjusted r2

# %%
def calculate_adj_r2(x, n, k):
    return 1 - ((1 - x) * (n - 1)) / (n - k - 1)

# %%
result_df['test_r2'].apply(lambda x: calculate_adj_r2(x, x_test.shape[0], x_train.shape[1]))
# Out:
# 0    1.000000
# 1    1.000000
# 2    1.000000
# 3    0.969909
# Name: test_r2, dtype: float64

# %%
def print_metrics(x_train_scaled, y_train,x_test_scaled, y_test):
    print('r2_score')
    print(lr.score(x_train_scaled, y_train), lr.score(x_test_scaled, y_test))
    print('mae')
    print(mean_absolute_error(y_train, lr.predict(x_train_scaled)),mean_absolute_error(y_test, lr.predict(x_test_scaled)))

# %%
lr = LinearRegression()
lr.fit(x_train_scaled, y_train)
lr.score(x_train_scaled, y_train), lr.score(x_test_scaled, y_test)
# Out:
# (1.0, 1.0)

# %%
print_metrics(x_train_scaled, y_train,x_test_scaled, y_test)
# Out:
# r2
# 1.0 1.0
# mae
# 2.24445727009709e-11 2.271947878917746e-11

# %%
lr = RandomForestRegressor(n_estimators=100)
lr.fit(x_train_scaled, y_train)
# Out:
# RandomForestRegressor()

# %%
print_metrics(x_train_scaled, y_train,x_test_scaled, y_test)
# Out:
# r2
# 0.9999998391938864 0.9999983190488994
# mae
# 0.7402800283693118 2.2739723572405692

# %%
lr = DecisionTreeRegressor(min_samples_leaf=20)
lr.fit(x_train_scaled, y_train)
print_metrics(x_train_scaled, y_train,x_test_scaled, y_test)
# Out:
# r2
# 0.9997222236706265 0.9997310599933578
# mae
# 35.93333619263901 38.71241992354475

# %%
lr = RandomForestRegressor(n_estimators=500,
                          max_depth=10)
lr.fit(x_train_scaled, y_train)
print_metrics(x_train_scaled, y_train,x_test_scaled, y_test)
# Out:
# r2
# 0.9999995841755702 0.9999911764712556
# mae
# 3.6655437271791578 6.10480479651443

# %%
lr.predict(x_train_scaled)
# Out:
# array([ 2496.51863963,  3075.53754492,  9384.70249242, ...,
#        12898.08054947,  8931.02849353,  7049.10156902])

# %%
y_train
# Out:
# 10703     2497.0
# 10930     3077.1
# 3886      9391.4
# 9268     12914.0
# 11326     4667.6
#           ...
# 8668      8605.4
# 8232     22395.7
# 7297     12890.1
# 6396      8930.9
# 5739      7050.6
# Name: claim, Length: 9874, dtype: float64

# %%
lr.feature_importances_
# Out:
# array([9.40489831e-05, 1.17240246e-05, 5.41614702e-06, 6.03564962e-06,
#        1.00740116e-05, 8.89308726e-07, 8.56778820e-07, 5.39336792e-08,
#        2.06476892e-08, 3.68743475e-08, 2.47592689e-08, 5.83391190e-07,
#        2.93120270e-07, 3.14927841e-06, 1.37356421e-07, 2.59932627e-06,
#        3.64552612e-08, 2.59131271e-06, 2.62575082e-06, 4.67852234e-07,
#        6.13010864e-08, 3.57902792e-08, 5.59770337e-09, 4.19594200e-08,
#        5.93878880e-08, 8.22704511e-08, 8.60171733e-08, 9.99857963e-01])

# %%
sns.heatmap(x_train_scaled.corr())
# Out:
# <AxesSubplot:>

# %%
lr = KNeighborsRegressor(n_neighbors=20, n_jobs=-1)
lr.fit(x_train_scaled, y_train)
print_metrics(x_train_scaled, y_train,x_test_scaled, y_test)
# Out:
# r2
# 0.9348220673689016 0.9235973703586694
# mae
# 1683.9230073931535 1816.8622068651275
